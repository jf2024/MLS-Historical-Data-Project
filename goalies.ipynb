# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
pd.set_option('display.min_rows', 500)  # <-add this!
pd.set_option('display.max_rows', 500)

#got here: https://stackoverflow.com/questions/34398054/ipython-notebook-cell-multiple-outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
goalies = pd.read_csv('all_goalkeepers.csv')

goalies.head()
rows = len(goalies.axes[0])
cols = len(goalies.axes[1])
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
#            Player Club POS  GP  GS  MINS  SHTS   SV  GA   GAA PKG/A   W   L  \
# 0       Mark Dodd  DAL  GK  31  31  2776   235  160  45  1.45   5/5  17  14
# 1      Tony Meola  MET  GK  29  29  2610   188  142  38  1.31   3/4  14  15
# 2  Mark Dougherty  TB   GK  28  28  2520   186  123  47  1.68  9/10  17  11
# 3    Jorge Campos  LA   GK  24  24  2160   133  100  27  1.13   0/1  13   8
# 4  Garth Lagerwey  KC   GK  23  22  1959   133   83  38  1.73   2/2  12  10
#
#    T  ShO    W%   Sv%  Year Season
# 0  0    6  54.8  68.1  1996    reg
# 1  0    9  48.3  75.5  1996    reg
# 2  0    3  60.7  66.1  1996    reg
# 3  0    4  54.2  75.2  1996    reg
# 4  0    3  52.2  62.4  1996    reg
# Number of Rows:  2006
# Number of Columns:  19

# %%
#get descriptive statistics for the goalies 
# and lets make it specific for goalies that played for SJ in the year 1996
goalies = pd.read_csv('all_goalkeepers.csv')

#future me, just grab goalies from sj, might have to filter more but use describe in the end to answer that first slide question

# %%
#

# %%
#idea for machine learning
# try and predict the standings at the end of the season based on historical precedent as well as any specific players that are playing
# for example, if a team has a player that has scored 10 goals in the last 5 games, that team is likely to be higher in the standings
# also, if a team has a goalie that has let in 10 goals in the last 5 games, that team is likely to be lower in the standings
